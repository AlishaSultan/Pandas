# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # value_counts()  -----> applicable in (Series and dataframe)
#
#
# rows ka frequency count bta dein ga

# %%
marks = pd.DataFrame([
    [100 , 160 , 70] ,
    [100 , 160 , 70] ,
    [100 , 160 , 70] ,
    [109 , 120 , 170] ,
    [780 , 160 , 70] ,
    [107 , 190 , 70] 
], columns = ['iq' , 'marks' , 'salary'])

marks
# Out:
#     iq  marks  salary
# 0  100    160      70
# 1  100    160      70
# 2  100    160      70
# 3  109    120     170
# 4  780    160      70
# 5  107    190      70

# %%
marks.value_counts()
# Out:
# iq   marks  salary
# 100  160    70        3
# 107  190    70        1
# 109  120    170       1
# 780  160    70        1
# dtype: int64

# %%
ipl = pd.read_csv("D:/Data_science/data_sets/datasets-session-17/ipl-matches.csv")

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # find which player has won most in final and qualifiers

# %%
ipl['MatchNumber']
# Out:
# 0            Final
# 1      Qualifier 2
# 2       Eliminator
# 3      Qualifier 1
# 4               70
#           ...
# 945              4
# 946              5
# 947              3
# 948              2
# 949              1
# Name: MatchNumber, Length: 950, dtype: object

# %%
ipl['MatchNumber'].str.isdigit()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 945     True
# 946     True
# 947     True
# 948     True
# 949     True
# Name: MatchNumber, Length: 950, dtype: bool

# %%
~ipl['MatchNumber'].str.isdigit()    #--------------------------> isdigit() digit hai yeh ni yeh batata hai
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
ipl[~ipl['MatchNumber'].str.isdigit() ]
# Out:
#           ID           City        Date   Season         MatchNumber  \
# 0    1312200      Ahmedabad  2022-05-29     2022               Final
# 1    1312199      Ahmedabad  2022-05-27     2022         Qualifier 2
# 2    1312198        Kolkata  2022-05-25     2022          Eliminator
# 3    1312197        Kolkata  2022-05-24     2022         Qualifier 1
# 74   1254117          Dubai  2021-10-15     2021               Final
# 75   1254116        Sharjah  2021-10-13     2021         Qualifier 2
# 76   1254115        Sharjah  2021-10-11     2021          Eliminator
# 77   1254114          Dubai  2021-10-10     2021         Qualifier 1
# 134  1237181            NaN  2020-11-10  2020/21               Final
# 135  1237180      Abu Dhabi  2020-11-08  2020/21         Qualifier 2
# 136  1237178      Abu Dhabi  2020-11-06  2020/21          Eliminator
# 137  1237177            NaN  2020-11-05  2020/21         Qualifier 1
# 194  1181768      Hyderabad  2019-05-12     2019               Final
# ...

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# KH Pandya            1
# ...

# %% [markdown]
# # Toss decision plot

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['TossDecision'].value_counts()
# Out:
# field    599
# bat      351
# Name: TossDecision, dtype: int64

# %%
ipl['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='TossDecision'>

# %% [markdown]
# # how many matches each team played

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %%
ipl['Team2'].value_counts()
# Out:
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Punjab Kings                    10
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: Team2, dtype: int64

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending = False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %% [markdown]
# # sort_values()   #-----------------> applicable in both series and dataframe

# %%
movies = pd.read_csv("D:/Data_science/data_sets/datasets-session-17/movies.csv")
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values('title_x')    #---------------> numbers oper ay gay then alphabet
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values('title_x' , ascending = False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
student = {
    'name' : ['alisha' , 'sonia' , np.nan , 'fareeha' , 'ayeza' , 'ayat' , np.nan , np.nan],
    'marks' : [56 , 89 , 23 , 45 , np.nan , 89 , 12 , np.nan],
    'college' : ['pucit' , 'fcit' , 'GCU' , np.nan , np.nan , np.nan , 'punjab college' , np.nan],
    'cgpa' : [4 , 3.4 , 2.5 , 3 , 4 , np.nan , np.nan , np.nan],
    'package' : [45 , 89 , 23 , 56 , 98 , np.nan , np.nan , np.nan]
    
    
}

students = pd.DataFrame(student)
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 4    ayeza    NaN             NaN   4.0     98.0
# 5     ayat   89.0             NaN   NaN      NaN
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students.sort_values('name')           #--------------> Nan sb neachy chalay jai gay
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 5     ayat   89.0             NaN   NaN      NaN
# 4    ayeza    NaN             NaN   4.0     98.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students.sort_values('name' , na_position = 'first')
# Out:
#       name  marks         college  cgpa  package
# 2      NaN   23.0             GCU   2.5     23.0
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN
# 0   alisha   56.0           pucit   4.0     45.0
# 5     ayat   89.0             NaN   NaN      NaN
# 4    ayeza    NaN             NaN   4.0     98.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 1    sonia   89.0            fcit   3.4     89.0

# %%
students.sort_values('name' , na_position = 'last')
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 5     ayat   89.0             NaN   NaN      NaN
# 4    ayeza    NaN             NaN   4.0     98.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students         #-------------> not permanant changes
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 4    ayeza    NaN             NaN   4.0     98.0
# 5     ayat   89.0             NaN   NaN      NaN
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students.sort_values('name' , na_position = 'last' , inplace = True)

# %%
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 5     ayat   89.0             NaN   NaN      NaN
# 4    ayeza    NaN             NaN   4.0     98.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %% [markdown]
# # multiple column sort:

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release' , 'title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release' , 'title_x'] , ascending = [True , False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# # rank  ----------> Series
#
#
# rank ------> batsman_run ky score ko rank kr daita hai like jis sy sb sy km bnai us ko 0 sy start karein gy then agay continue upto maximum level

# %%
bats = pd.read_csv("D:/Data_science/data_sets/datasets-session-17/batsman_runs_ipl.csv")    #-------> default behaiour ascending
bats
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
bats['batsman_run'].rank()                     #-------> default behaiour ascending
# Out:
# 0      439.5
# 1      380.0
# 2       71.0
# 3      277.0
# 4      203.5
#        ...
# 600     12.0
# 601    263.0
# 602     58.5
# 603    579.0
# 604    350.0
# Name: batsman_run, Length: 605, dtype: float64

# %%
bats['batsman_run'].rank(ascending = False)
# Out:
# 0      166.5
# 1      226.0
# 2      535.0
# 3      329.0
# 4      402.5
#        ...
# 600    594.0
# 601    343.0
# 602    547.5
# 603     27.0
# 604    256.0
# Name: batsman_run, Length: 605, dtype: float64

# %%
# new column add

# %%
bats['bats_man rank']=bats['batsman_run'].rank(ascending = False)

# %%
bats
# Out:
#              batter  batsman_run  bats_man rank
# 0    A Ashish Reddy          280          166.5
# 1          A Badoni          161          226.0
# 2        A Chandila            4          535.0
# 3          A Chopra           53          329.0
# 4       A Choudhary           25          402.5
# ..              ...          ...            ...
# 600      Yash Dayal            0          594.0
# 601   Yashpal Singh           47          343.0
# 602     Younis Khan            3          547.5
# 603    Yuvraj Singh         2754           27.0
# 604          Z Khan          117          256.0
#
# [605 rows x 3 columns]

# %%
bats.sort_values('bats_man rank')
# Out:
#            batter  batsman_run  bats_man rank
# 569       V Kohli         6634            1.0
# 462      S Dhawan         6244            2.0
# 130     DA Warner         5883            3.0
# 430     RG Sharma         5881            4.0
# 493      SK Raina         5536            5.0
# ..            ...          ...            ...
# 512   SS Cottrell            0          594.0
# 466     S Kaushik            0          594.0
# 203     IC Pandey            0          594.0
# 467       S Ladda            0          594.0
# 468  S Lamichhane            0          594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# # sort_index ----------------> (series and dataframe)

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_index(ascending = False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# # set_index          #------------------------> dataframe

# %%
bats
# Out:
#              batter  batsman_run  bats_man rank
# 0    A Ashish Reddy          280          166.5
# 1          A Badoni          161          226.0
# 2        A Chandila            4          535.0
# 3          A Chopra           53          329.0
# 4       A Choudhary           25          402.5
# ..              ...          ...            ...
# 600      Yash Dayal            0          594.0
# 601   Yashpal Singh           47          343.0
# 602     Younis Khan            3          547.5
# 603    Yuvraj Singh         2754           27.0
# 604          Z Khan          117          256.0
#
# [605 rows x 3 columns]

# %%
bats.set_index('batter')    #---------------------> temporary operation
# Out:
#                 batsman_run  bats_man rank
# batter
# A Ashish Reddy          280          166.5
# A Badoni                161          226.0
# A Chandila                4          535.0
# A Chopra                 53          329.0
# A Choudhary              25          402.5
# ...                     ...            ...
# Yash Dayal                0          594.0
# Yashpal Singh            47          343.0
# Younis Khan               3          547.5
# Yuvraj Singh           2754           27.0
# Z Khan                  117          256.0
#
# [605 rows x 2 columns]

# %%
bats
# Out:
#              batter  batsman_run  bats_man rank
# 0    A Ashish Reddy          280          166.5
# 1          A Badoni          161          226.0
# 2        A Chandila            4          535.0
# 3          A Chopra           53          329.0
# 4       A Choudhary           25          402.5
# ..              ...          ...            ...
# 600      Yash Dayal            0          594.0
# 601   Yashpal Singh           47          343.0
# 602     Younis Khan            3          547.5
# 603    Yuvraj Singh         2754           27.0
# 604          Z Khan          117          256.0
#
# [605 rows x 3 columns]

# %%
bats.set_index('batter' , inplace = True)

# %%
bats
# Out:
#                 batsman_run  bats_man rank
# batter
# A Ashish Reddy          280          166.5
# A Badoni                161          226.0
# A Chandila                4          535.0
# A Chopra                 53          329.0
# A Choudhary              25          402.5
# ...                     ...            ...
# Yash Dayal                0          594.0
# Yashpal Singh            47          343.0
# Younis Khan               3          547.5
# Yuvraj Singh           2754           27.0
# Z Khan                  117          256.0
#
# [605 rows x 2 columns]

# %% [markdown]
# # reset_index            ________applicable in both dataframe and series

# %%
bats
# Out:
#                 batsman_run  bats_man rank
# batter
# A Ashish Reddy          280          166.5
# A Badoni                161          226.0
# A Chandila                4          535.0
# A Chopra                 53          329.0
# A Choudhary              25          402.5
# ...                     ...            ...
# Yash Dayal                0          594.0
# Yashpal Singh            47          343.0
# Younis Khan               3          547.5
# Yuvraj Singh           2754           27.0
# Z Khan                  117          256.0
#
# [605 rows x 2 columns]

# %%
bats.reset_index()                #----------------------> not permanent
# Out:
#              batter  batsman_run  bats_man rank
# 0    A Ashish Reddy          280          166.5
# 1          A Badoni          161          226.0
# 2        A Chandila            4          535.0
# 3          A Chopra           53          329.0
# 4       A Choudhary           25          402.5
# ..              ...          ...            ...
# 600      Yash Dayal            0          594.0
# 601   Yashpal Singh           47          343.0
# 602     Younis Khan            3          547.5
# 603    Yuvraj Singh         2754           27.0
# 604          Z Khan          117          256.0
#
# [605 rows x 3 columns]

# %% [markdown]
# # I want to check the index with bats_man rank without loosing

# %% [markdown]
# # one way but not work

# %%
bats
# Out:
#                 batsman_run  bats_man rank
# batter
# A Ashish Reddy          280          166.5
# A Badoni                161          226.0
# A Chandila                4          535.0
# A Chopra                 53          329.0
# A Choudhary              25          402.5
# ...                     ...            ...
# Yash Dayal                0          594.0
# Yashpal Singh            47          343.0
# Younis Khan               3          547.5
# Yuvraj Singh           2754           27.0
# Z Khan                  117          256.0
#
# [605 rows x 2 columns]

# %%
bats.set_index('bats_man rank')     #-----------------> batter lost
# Out:
#                batsman_run
# bats_man rank
# 166.5                  280
# 226.0                  161
# 535.0                    4
# 329.0                   53
# 402.5                   25
# ...                    ...
# 594.0                    0
# 343.0                   47
# 547.5                    3
# 27.0                  2754
# 256.0                  117
#
# [605 rows x 1 columns]

# %% [markdown]
# # valid way

# %%
bats.reset_index().set_index('bats_man rank')
# Out:
#                        batter  batsman_run
# bats_man rank
# 166.5          A Ashish Reddy          280
# 226.0                A Badoni          161
# 535.0              A Chandila            4
# 329.0                A Chopra           53
# 402.5             A Choudhary           25
# ...                       ...          ...
# 594.0              Yash Dayal            0
# 343.0           Yashpal Singh           47
# 547.5             Younis Khan            3
# 27.0             Yuvraj Singh         2754
# 256.0                  Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# # jab hum series py reset_index lagai gay tu wo dataframe bn jai ga
#
#
# series converted into dataframe

# %% [markdown]
# # rename               ------------->dataframe

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.set_index('title_x' , inplace = True)

# %%
movies
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(columns = {'imdb_id' : 'imdb' , 'poster_path' : 'link'})   #----------------> not permanent
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(columns = {'imdb_id' : 'imdb' , 'poster_path' : 'link'} , inplace = True)

# %%
movies
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# # index ka name be badal sakhty hai

# %%
movies.rename(index = {'Yeh Zindagi Ka Safar' : 89 , 'Daaka' : '78'})
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# 89                                     tt0298607
# Sabse Bada Sukh                        tt0069204
# 78                                    tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# # unique  -------------->(Series)
#
#
# nan ko be count krta hai

# %%
series=pd.Series([1 , 2 , 3 ,1  , 1 , 3 , 2 , 4 , 6, 7 , 8 ,9 , 5 ,6 , 7 ,8 ,9])
series.unique()
# Out:
# array([1, 2, 3, 4, 6, 7, 8, 9, 5], dtype=int64)

# %%
series=pd.Series([1 , 2 , 3 ,1  , 1 ,np.nan ,  3 , 2 , 4 , 6, 7 ,np.nan ,  8 ,9 , 5 ,6 ,np.nan ,  7 ,8 ,9])
series.unique()
# Out:
# array([ 1.,  2.,  3., nan,  4.,  6.,  7.,  8.,  9.,  5.])

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
len(ipl['Season'].unique())
# Out:
# 15

# %% [markdown]
# # 2nd method

# %% [markdown]
# # nunique  ----------------> series and dataframe -----------> nan ko count ni krta

# %%
ipl['Season'].nunique()
# Out:
# 15

# %%
series=pd.Series([1 , 2 , 3  ,np.nan , 4 , 6, 7 ,np.nan ,  8 ,9 ,np.nan])
len(series)
# Out:
# 11

# %%
series.nunique()
# Out:
# 8

# %% [markdown]
# # isnull -------------------> series + dataframe

# %%
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 5     ayat   89.0             NaN   NaN      NaN
# 4    ayeza    NaN             NaN   4.0     98.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students['name'].isnull()
# Out:
# 0    False
# 5    False
# 4    False
# 3    False
# 1    False
# 2     True
# 6     True
# 7     True
# Name: name, dtype: bool

# %%
students['name'][students['name'].isnull()]
# Out:
# 2    NaN
# 6    NaN
# 7    NaN
# Name: name, dtype: object

# %% [markdown]
# # notnull -------------------->applicable in both series and dataframe

# %%
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 5     ayat   89.0             NaN   NaN      NaN
# 4    ayeza    NaN             NaN   4.0     98.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students['college'].notnull()
# Out:
# 0     True
# 5    False
# 4    False
# 3    False
# 1     True
# 2     True
# 6     True
# 7    False
# Name: college, dtype: bool

# %%
students['college'][students['college'].notnull()]
# Out:
# 0             pucit
# 1              fcit
# 2               GCU
# 6    punjab college
# Name: college, dtype: object

# %% [markdown]
# # hasnans ----------------------------> series

# %%
students['college'].hasnans
# Out:
# True

# %%
students.isnull()
# Out:
#     name  marks  college   cgpa  package
# 0  False  False    False  False    False
# 5  False  False     True   True     True
# 4  False   True     True  False    False
# 3  False  False     True  False    False
# 1  False  False    False  False    False
# 2   True  False    False  False    False
# 6   True  False    False   True     True
# 7   True   True     True   True     True

# %%
students.notnull()
# Out:
#     name  marks  college   cgpa  package
# 0   True   True     True   True     True
# 5   True   True    False  False    False
# 4   True  False    False   True     True
# 3   True   True    False   True     True
# 1   True   True     True   True     True
# 2  False   True     True   True     True
# 6  False   True     True  False    False
# 7  False  False    False  False    False

# %% [markdown]
# # dropna -------------> both applicable in series and dataframe

# %%
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 5     ayat   89.0             NaN   NaN      NaN
# 4    ayeza    NaN             NaN   4.0     98.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students['name'].dropna()
# Out:
# 0     alisha
# 5       ayat
# 4      ayeza
# 3    fareeha
# 1      sonia
# Name: name, dtype: object

# %%
students.dropna()        # ________________kise be row mei agr ak jagah missing value hai tu us pore row ho he hata de ga
# Out:
#      name  marks college  cgpa  package
# 0  alisha   56.0   pucit   4.0     45.0
# 1   sonia   89.0    fcit   3.4     89.0

# %%
students.dropna(how = 'any')    #___________jaha be missing value hoo ge sb ko hata dein ga default behaviour
# Out:
#      name  marks college  cgpa  package
# 0  alisha   56.0   pucit   4.0     45.0
# 1   sonia   89.0    fcit   3.4     89.0

# %%
student = {
    'name' : ['alisha' , 'sonia' , np.nan , 'fareeha' , 'ayeza' , 'ayat' , np.nan , np.nan],
    'marks' : [56 , 89 , 23 , 45 , np.nan , 89 , 12 , np.nan],
    'college' : ['pucit' , 'fcit' , 'GCU' , np.nan , np.nan , np.nan , 'punjab college' , np.nan],
    'cgpa' : [4 , 3.4 , 2.5 , 3 , 4 , np.nan , np.nan , np.nan],
    'package' : [45 , 89 , 23 , 56 , 98 , np.nan , np.nan , np.nan]
    
    
}

students = pd.DataFrame(student)
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 4    ayeza    NaN             NaN   4.0     98.0
# 5     ayat   89.0             NaN   NaN      NaN
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students.dropna(how = 'all')       #-------------->  7 row will delete
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 4    ayeza    NaN             NaN   4.0     98.0
# 5     ayat   89.0             NaN   NaN      NaN
# 6      NaN   12.0  punjab college   NaN      NaN

# %%
students.dropna(subset = ['name'])       #name ke basis py null values remove hoo ge
# Out:
#       name  marks college  cgpa  package
# 0   alisha   56.0   pucit   4.0     45.0
# 1    sonia   89.0    fcit   3.4     89.0
# 3  fareeha   45.0     NaN   3.0     56.0
# 4    ayeza    NaN     NaN   4.0     98.0
# 5     ayat   89.0     NaN   NaN      NaN

# %%
students.dropna(subset = ['name' , 'cgpa'])    #OR operation
# Out:
#       name  marks college  cgpa  package
# 0   alisha   56.0   pucit   4.0     45.0
# 1    sonia   89.0    fcit   3.4     89.0
# 3  fareeha   45.0     NaN   3.0     56.0
# 4    ayeza    NaN     NaN   4.0     98.0

# %% [markdown]
# # fillna ------------> series + dataframe

# %%
students['name'].fillna('unknown')
# Out:
# 0     alisha
# 1      sonia
# 2    unknown
# 3    fareeha
# 4      ayeza
# 5       ayat
# 6    unknown
# 7    unknown
# Name: name, dtype: object

# %%
students['name'].fillna('unknown').hasnans
# Out:
# False

# %%
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 4    ayeza    NaN             NaN   4.0     98.0
# 5     ayat   89.0             NaN   NaN      NaN
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students.fillna(0)
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2        0   23.0             GCU   2.5     23.0
# 3  fareeha   45.0               0   3.0     56.0
# 4    ayeza    0.0               0   4.0     98.0
# 5     ayat   89.0               0   0.0      0.0
# 6        0   12.0  punjab college   0.0      0.0
# 7        0    0.0               0   0.0      0.0

# %%
students['name']
# Out:
# 0     alisha
# 1      sonia
# 2        NaN
# 3    fareeha
# 4      ayeza
# 5       ayat
# 6        NaN
# 7        NaN
# Name: name, dtype: object

# %%
students['name'].fillna(method = 'ffill')       # jo NaN sy oper value hoo ge wahe neachy aa jai ge   (forward fill)
# Out:
# 0     alisha
# 1      sonia
# 2      sonia
# 3    fareeha
# 4      ayeza
# 5       ayat
# 6       ayat
# 7       ayat
# Name: name, dtype: object

# %%
students['name'].fillna(method = 'bfill')      #jo NaN sy neachy value hoo ge wahe  aa jai ge   (before fill)
# Out:
# 0     alisha
# 1      sonia
# 2    fareeha
# 3    fareeha
# 4      ayeza
# 5       ayat
# 6        NaN
# 7        NaN
# Name: name, dtype: object

# %% [markdown]
# # drop_duplicates ---------> applicable in both series and dataframe

# %%
marks
# Out:
#     iq  marks  salary
# 0  100    160      70
# 1  100    160      70
# 2  100    160      70
# 3  109    120     170
# 4  780    160      70
# 5  107    190      70

# %%
marks.duplicated()               #------------->tell the row which are duplicated
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
drop = pd.Series([1 , 2 , 2 , 3 , 4 , 6, 6 , 4 , 3 , 8 , 9])
drop.drop_duplicates()
# Out:
# 0     1
# 1     2
# 3     3
# 4     4
# 5     6
# 9     8
# 10    9
# dtype: int64

# %%
marks
# Out:
#     iq  marks  salary
# 0  100    160      70
# 1  100    160      70
# 2  100    160      70
# 3  109    120     170
# 4  780    160      70
# 5  107    190      70

# %%
marks.drop_duplicates()
# Out:
#     iq  marks  salary
# 0  100    160      70
# 3  109    120     170
# 4  780    160      70
# 5  107    190      70

# %%
marks.drop_duplicates(keep = 'first')
# Out:
#     iq  marks  salary
# 0  100    160      70
# 3  109    120     170
# 4  780    160      70
# 5  107    190      70

# %%
marks.drop_duplicates(keep = 'last')
# Out:
#     iq  marks  salary
# 2  100    160      70
# 3  109    120     170
# 4  780    160      70
# 5  107    190      70

# %% [markdown]
# # find the last match played by virat kohli in Delhi

# %%
ipl['all players'] = ipl['Team1Players'] + ipl['Team2Players']

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#         WinningTeam    WonBy Margin  method Player_of_Match  \
# 0    Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1  Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# ...

# %%
def find_kohli(players_list):
    return 'V Kohli' in players_list

# %%
ipl['did kohli play']=ipl['all players'].apply(find_kohli)

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
(ipl['City'] == 'Delhi') & (ipl['did kohli play'] == True)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
ipl[(ipl['City'] == 'Delhi') & (ipl['did kohli play'] == True)]
# Out:
#           ID   City        Date   Season MatchNumber             Team1  \
# 208  1178421  Delhi  2019-04-28     2019          46    Delhi Capitals
# 269  1136605  Delhi  2018-05-12     2018          45  Delhi Daredevils
# 318  1082646  Delhi  2017-05-14     2017          56  Delhi Daredevils
# 467   829757  Delhi  2015-04-26     2015          26  Delhi Daredevils
# 571   598054  Delhi  2013-05-10     2013          57  Delhi Daredevils
# 638   548372  Delhi  2012-05-17     2012          67  Delhi Daredevils
# 746   501227  Delhi  2011-04-26     2011          30  Delhi Daredevils
# 801   419140  Delhi  2010-04-04  2009/10          35  Delhi Daredevils
# 933   335998  Delhi  2008-04-30  2007/08          17  Delhi Daredevils
#
#                            Team2                 Venue  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium
# 269  Royal Challengers Bangalore  Arun Jaitley Stadium
# 318  Royal Challengers Bangalore      Feroz Shah Kotla
# ...

# %%
ipl[(ipl['City'] == 'Delhi') & (ipl['did kohli play'] == True)].drop_duplicates(subset = ['City' , 'did kohli play'] , keep = 'first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did kohli play
# 208           True
#
# [1 rows x 22 columns]

# %% [markdown]
# # drop        -----------------> applicable in both series and dataframe
#
# delete the rows ad columns

# %%
temp = pd.Series([23 , 56 , 78 , 34 , 76 , 990])
temp
# Out:
# 0     23
# 1     56
# 2     78
# 3     34
# 4     76
# 5    990
# dtype: int64

# %%
temp.drop(index = [0 , 5])
# Out:
# 1    56
# 2    78
# 3    34
# 4    76
# dtype: int64

# %%
students
# Out:
#       name  marks         college  cgpa  package
# 0   alisha   56.0           pucit   4.0     45.0
# 1    sonia   89.0            fcit   3.4     89.0
# 2      NaN   23.0             GCU   2.5     23.0
# 3  fareeha   45.0             NaN   3.0     56.0
# 4    ayeza    NaN             NaN   4.0     98.0
# 5     ayat   89.0             NaN   NaN      NaN
# 6      NaN   12.0  punjab college   NaN      NaN
# 7      NaN    NaN             NaN   NaN      NaN

# %%
students.drop(columns = ['package' , 'cgpa'])
# Out:
#       name  marks         college
# 0   alisha   56.0           pucit
# 1    sonia   89.0            fcit
# 2      NaN   23.0             GCU
# 3  fareeha   45.0             NaN
# 4    ayeza    NaN             NaN
# 5     ayat   89.0             NaN
# 6      NaN   12.0  punjab college
# 7      NaN    NaN             NaN

# %%
students.drop(index = [2 , 6 , 7])
# Out:
#       name  marks college  cgpa  package
# 0   alisha   56.0   pucit   4.0     45.0
# 1    sonia   89.0    fcit   3.4     89.0
# 3  fareeha   45.0     NaN   3.0     56.0
# 4    ayeza    NaN     NaN   4.0     98.0
# 5     ayat   89.0     NaN   NaN      NaN

# %% [markdown]
# # apply(series + dataframe)

# %%
temp = pd.Series([12 , 45 , 67 , 23 , 56 , 89])
temp
# Out:
# 0    12
# 1    45
# 2    67
# 3    23
# 4    56
# 5    89
# dtype: int64

# %%
def sigmoid(value):
    return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.000006
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# 5    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def eucledian(row):
    pt_A = row['1st point']
    pt_B = row['2nd point']
    
    return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df.apply(eucledian , axis = 1)
# Out:
# 0     6.000000
# 1     7.810250
# 2     2.828427
# 3    21.931712
# 4     5.000000
# dtype: float64

# %%
points_df['distance'] = points_df.apply(eucledian , axis = 1)

# %%
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
