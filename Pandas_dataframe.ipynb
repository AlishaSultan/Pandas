# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# In[3]:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating dataframes<br>
# <br>
# koi be tabular data hai jb hum usay pandas mei load krty hai tu dataframe ke tarah act krta hai.jis ko hum table bolaty hai pandas use ko dataframe bolata hai......2d structure of data using rows and columns.dataframe ky andar jo har single column hoo ga usay series bolaya jata hai...... also dataframe ke har single row is also a series

# %% [markdown]
# # using list:

# %% [markdown]
# In[4]:

# %%
data = [
    
    [100 , 140 , 16],
    [98 , 134 , 34],
    [45 , 67 , 23],
    [67, 190 , 45]
]

# %%
list_students =pd.DataFrame(data , columns = ['iq' , 'marks' , 'package'])

# %% [markdown]
# utomatically index generates

# %% [markdown]
# In[5]:

# %%
data = [
    
    [100 , 140 , 16],
    [98 , 134 , 34],
    [45 , 67 , 23],
    [67, 190 , 45]
]

# %%
list_students = pd.DataFrame(data , columns = ['iq' , 'marks' , 'package'] , index = ['student1' , 'student2' , 'student3' , 'student4'])

# %% [markdown]
# In[6]:

# %%
type(list_students)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # using dict:

# %% [markdown]
# In[7]:

# %%
dict_data = {
    
    'iq' : [100 , 98 , 45 , 67],
    'marks' : [140 , 134 , 67 , 23],
    'package' : [16 , 34 , 23 , 45]
    
}

# %%
students = pd.DataFrame(dict_data)

# %% [markdown]
# In[8]:

# %%
dict_data = {
    
    'iq' : [100 , 98 , 45 , 67],
    'marks' : [140 , 134 , 67 , 23],
    'package' : [16 , 34 , 23 , 45]
    
}

# %%
students=pd.DataFrame(dict_data , index = ['student1' , 'student2' , 'student3' , 'student4'])

# %% [markdown]
# In[9]:

# %%
type(students)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # read_csv

# %% [markdown]
# In[10]:

# %%
movies = pd.read_csv('D:/Data_science/data_sets/datasets-session-17/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# In[11]:

# %%
ipl = pd.read_csv('D:/Data_science/data_sets/datasets-session-17/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # Dataframe Attributes and Methods:

# %% [markdown]
# # shape

# %% [markdown]
# In[12]:

# %%
movies.shape
# Out:
# (1629, 18)

# %% [markdown]
# In[13]:

# %%
ipl.shape
# Out:
# (950, 20)

# %% [markdown]
# # dtypes<br>
# <br>
# dataframe consists of series.....or series ka alg alg datatype hoo ga

# %% [markdown]
# In[14]:

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %% [markdown]
# In[15]:

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %% [markdown]
# # index

# %% [markdown]
# In[16]:

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %% [markdown]
# In[17]:

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %% [markdown]
# # columns

# %% [markdown]
# In[18]:

# %%
movies.columns          #-----------------> given in list
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %% [markdown]
# In[19]:

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# # values

# %% [markdown]
# In[20]:

# %%
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %% [markdown]
# In[21]:

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %% [markdown]
# # head and tail

# %% [markdown]
# In[22]:

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %% [markdown]
# In[23]:

# %%
movies.tail()
# Out:
#                     title_x     imdb_id  \
# 1624  Tera Mera Saath Rahen   tt0301250
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1626        Sabse Bada Sukh   tt0069204
# 1627                  Daaka  tt10833860
# 1628               Humsafar   tt2403201
#
#                                             poster_path  \
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
# ...

# %% [markdown]
# # sample<br>
# <br>
# randomly gives one row

# %% [markdown]
# In[24]:

# %%
movies.sample()
# Out:
#           title_x    imdb_id  \
# 1589  Chandni Bar  tt0267363
#
#                                             poster_path  \
# 1589  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link      title_y original_title  \
# 1589  https://en.wikipedia.org/wiki/Chandni_Bar  Chandni Bar    Chandni Bar
#
#       is_adult  year_of_release runtime       genres  imdb_rating  imdb_votes  \
# 1589         0             2001     150  Crime|Drama          7.6        2284
#
#                                                   story  \
# 1589  Mumtaz is a village girl whose family is kille...
#
#                                                 summary tagline  \
# 1589  A displaced woman is forced to become a beer-b...     NaN
#
#                                                  actors  \
# 1589  Tabu|Atul Kulkarni|Rajpal Yadav|Shri Vallabh V...
#
#              wins_nominations               release_date
# ...

# %% [markdown]
# In[25]:

# %%
ipl.sample()
# Out:
#          ID    City        Date Season MatchNumber           Team1  \
# 576  598050  Mumbai  2013-05-07   2013          53  Mumbai Indians
#
#                      Team2             Venue      TossWinner TossDecision  \
# 576  Kolkata Knight Riders  Wankhede Stadium  Mumbai Indians          bat
#
#     SuperOver     WinningTeam WonBy  Margin method Player_of_Match  \
# 576         N  Mumbai Indians  Runs    65.0    NaN    SR Tendulkar
#
#                                           Team1Players  \
# 576  ['DR Smith', 'SR Tendulkar', 'KD Karthik', 'RG...
#
#                                           Team2Players          Umpire1  \
# 576  ['MS Bisla', 'G Gambhir', 'JH Kallis', 'YK Pat...  HDPK Dharmasena
#
#     Umpire2
# 576  S Ravi

# %% [markdown]
# # info

# %% [markdown]
# In[26]:

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %% [markdown]
# n tagline values are missing......

# %% [markdown]
# In[27]:

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# # describe<br>
# <br>
# jis jis column mei mathematical operations perform hoo sakhty hai woo show kr dein ga

# %% [markdown]
# In[28]:

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %% [markdown]
# In[29]:

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %% [markdown]
# # isnull()<br>
# <br>
# shows the boolean (True false)--------->where null value it gives null

# %% [markdown]
# In[30]:

# %%
movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %% [markdown]
# In[31]:

# %%
movies.isnull().sum()           #It tell how much null values
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %% [markdown]
# In[32]:

# %%
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %% [markdown]
# In[33]:

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %% [markdown]
# # duplicated

# %% [markdown]
# In[34]:

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %% [markdown]
# In[35]:

# %%
movies.duplicated().sum()
# Out:
# 0

# %% [markdown]
# In[36]:

# %%
ipl.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %% [markdown]
# In[37]:

# %%
ipl.duplicated().sum()
# Out:
# 0

# %% [markdown]
# In[38]:

# %%
dict_data = {
    
    'iq' : [100 , 98 , 45 , 67 , 0 , 0],
    'marks' : [140 , 134 , 67 , 23 , 0 , 0],
    'package' : [16 , 34 , 23 , 45 , 0 , 0]
    
}

# %%
students = pd.DataFrame(dict_data)

# %%
students
# Out:
#     iq  marks  package
# 0  100    140       16
# 1   98    134       34
# 2   45     67       23
# 3   67     23       45
# 4    0      0        0
# 5    0      0        0

# %% [markdown]
# In[39]:

# %%
students.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# In[40]:

# %%
students.duplicated().sum()         # ONE ROW IS DUPLICATED
# Out:
# 1

# %% [markdown]
# # rename

# %% [markdown]
# In[41]:

# %%
students.rename(columns = {'marks' : 'percent','package' : 'LPA'})    #------------> not permanent changes
# Out:
#     iq  percent  LPA
# 0  100      140   16
# 1   98      134   34
# 2   45       67   23
# 3   67       23   45
# 4    0        0    0
# 5    0        0    0

# %% [markdown]
# # permanent changes krne hai tu

# %% [markdown]
# In[42]:

# %%
students.rename(columns = {'marks' : 'percent','package' : 'LPA'} , inplace = 'True')

# %% [markdown]
# In[43]:

# %%
students
# Out:
#     iq  percent  LPA
# 0  100      140   16
# 1   98      134   34
# 2   45       67   23
# 3   67       23   45
# 4    0        0    0
# 5    0        0    0

# %% [markdown]
# # math methods:

# %% [markdown]
# # sum<br>
# <br>
# sum the column even strings it can concatenate

# %% [markdown]
# In[44]:

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# In[45]:

# %%
movies.sum()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2720\2790600498.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.sum()
# title_x            Uri: The Surgical StrikeBattalion 609The Accid...
# imdb_id            tt8291224tt9472208tt6986710tt8108208tt6028796t...
# wiki_link          https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y            Uri: The Surgical StrikeBattalion 609The Accid...
# original_title     Uri: The Surgical StrikeBattalion 609The Accid...
# is_adult                                                           0
# year_of_release                                              3274720
# runtime            1381311121211029710910414812013415314313014311...
# ...

# %% [markdown]
# In[46]:

# %%
students
# Out:
#     iq  percent  LPA
# 0  100      140   16
# 1   98      134   34
# 2   45       67   23
# 3   67       23   45
# 4    0        0    0
# 5    0        0    0

# %% [markdown]
# In[47]:

# %%
students.sum()
# Out:
# iq         310
# percent    364
# LPA        118
# dtype: int64

# %% [markdown]
# In[48]:

# %%
students.sum(axis = 0)
# Out:
# iq         310
# percent    364
# LPA        118
# dtype: int64

# %% [markdown]
# In[49]:

# %%
students.sum(axis = 1)
# Out:
# 0    256
# 1    266
# 2    135
# 3    135
# 4      0
# 5      0
# dtype: int64

# %% [markdown]
# # mean

# %% [markdown]
# In[50]:

# %%
students.mean()
# Out:
# iq         51.666667
# percent    60.666667
# LPA        19.666667
# dtype: float64

# %% [markdown]
# # median

# %% [markdown]
# In[51]:

# %%
students.median()
# Out:
# iq         56.0
# percent    45.0
# LPA        19.5
# dtype: float64

# %% [markdown]
# # mode

# %% [markdown]
# In[52]:

# %%
students.mode()
# Out:
#    iq  percent  LPA
# 0   0        0    0

# %% [markdown]
# # min

# %% [markdown]
# In[53]:

# %%
students.min()
# Out:
# iq         0
# percent    0
# LPA        0
# dtype: int64

# %% [markdown]
# # max

# %% [markdown]
# In[54]:

# %%
students.max()
# Out:
# iq         100
# percent    140
# LPA         45
# dtype: int64

# %% [markdown]
# # std

# %% [markdown]
# In[55]:

# %%
students.std()
# Out:
# iq         44.947377
# percent    64.017706
# LPA        18.140195
# dtype: float64

# %% [markdown]
# # var

# %% [markdown]
# In[56]:

# %%
students.var()
# Out:
# iq         2020.266667
# percent    4098.266667
# LPA         329.066667
# dtype: float64

# %% [markdown]
# # Selecting col from dataframe

# %% [markdown]
# # single column<br>
# <br>
# <br>
# ak single column series hota ha

# %% [markdown]
# In[57]:

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# In[58]:

# %%
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %% [markdown]
# In[59]:

# %%
type(movies['title_x'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# In[60]:

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# In[61]:

# %%
ipl['WinningTeam']
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2      Royal Challengers Bangalore
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945          Kolkata Knight Riders
# 946    Royal Challengers Bangalore
# 947               Delhi Daredevils
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: WinningTeam, Length: 950, dtype: object

# %% [markdown]
# type(ipl['WinningTeam'])

# %% [markdown]
# # multiple columns

# %% [markdown]
# In[62]:

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# In[63]:

# %%
movies[['poster_path' , 'title_y' ,'title_x' ]]
# Out:
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...                                                 ...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                             title_y                               title_x
# 0          Uri: The Surgical Strike              Uri: The Surgical Strike
# 1                     Battalion 609                         Battalion 609
# ...

# %% [markdown]
# In[64]:

# %%
type(movies[['poster_path' , 'title_y' ,'title_x' ]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # one column series hoo ge or multiple column dataframe hoo ga

# %% [markdown]
# In[65]:

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# In[66]:

# %%
ipl[['Team1' , 'Team2' ,'WinningTeam' ]]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# # Selecting rows from dataframe

# %% [markdown]
# In[67]:

# %%
dict_data = {
     'name' : ['kainat' , 'maryam' , 'alisha' , 'ayesha' , 'abeera' , 'alia'],
    'iq' : [100 , 98 , 45 , 67 , 0 , 0],
    'marks' : [140 , 134 , 67 , 23 , 0 , 0],
    'package' : [16 , 34 , 23 , 45 , 0 , 0]
    
}

# %%
students = pd.DataFrame(dict_data)

# %%
students.set_index('name' , inplace = True)  #-----------------> by making the column as a index

# %%
students
# Out:
#          iq  marks  package
# name
# kainat  100    140       16
# maryam   98    134       34
# alisha   45     67       23
# ayesha   67     23       45
# abeera    0      0        0
# alia      0      0        0

# %% [markdown]
# # iloc:<br>
#     <br>
#     <br>
#     Searching using index positions<br>
#     <br>

# %% [markdown]
# # loc:<br>
#     <br>
#     Searching using index labels

# %% [markdown]
# In[68]:

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# In[69]:

# %%
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %% [markdown]
# # multiple rows

# %% [markdown]
# In[70]:

# %%
movies.iloc[0 : 5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %% [markdown]
# In[71]:

# %%
movies.iloc[0 : 15 : 2]
# Out:
#                                  title_x    imdb_id  \
# 0               Uri: The Surgical Strike  tt8291224
# 2   The Accidental Prime Minister (film)  tt6986710
# 4                        Evening Shadows  tt6028796
# 6                          Fraud Saiyaan  tt5013008
# 8       Manikarnika: The Queen of Jhansi  tt6903440
# 10                                Amavas  tt8396186
# 12                             Hum Chaar  tt9319812
# 14                            Sonchiriya  tt8108200
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 2   https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                 NaN
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
# 14  https://upload.wikimedia.org/wikipedia/en/thum...
#
# ...

# %% [markdown]
# # fancy indexing

# %% [markdown]
# In[72]:

# %%
movies.iloc[[2 , 6, 8]]
# Out:
#                                 title_x    imdb_id  \
# 2  The Accidental Prime Minister (film)  tt6986710
# 6                         Fraud Saiyaan  tt5013008
# 8      Manikarnika: The Queen of Jhansi  tt6903440
#
#                                          poster_path  \
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
# 8  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 6        https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 8  https://en.wikipedia.org/wiki/Manikarnika:_The...
#
#                             title_y                    original_title  \
# 2     The Accidental Prime Minister     The Accidental Prime Minister
# 6                     Fraud Saiyaan                     Fraud Saiyyan
# 8  Manikarnika: The Queen of Jhansi  Manikarnika: The Queen of Jhansi
#
# ...

# %% [markdown]
# # loc

# %% [markdown]
# In[73]:

# %%
students
# Out:
#          iq  marks  package
# name
# kainat  100    140       16
# maryam   98    134       34
# alisha   45     67       23
# ayesha   67     23       45
# abeera    0      0        0
# alia      0      0        0

# %% [markdown]
# In[74]:

# %%
students.loc['alisha']
# Out:
# iq         45
# marks      67
# package    23
# Name: alisha, dtype: int64

# %% [markdown]
# # multiple

# %% [markdown]
# In[75]:

# %%
students.loc['maryam' : 'alia']               #-------->last included
# Out:
#         iq  marks  package
# name
# maryam  98    134       34
# alisha  45     67       23
# ayesha  67     23       45
# abeera   0      0        0
# alia     0      0        0

# %% [markdown]
# In[76]:

# %%
students.loc['maryam' : 'alia' : 2]
# Out:
#         iq  marks  package
# name
# maryam  98    134       34
# ayesha  67     23       45
# alia     0      0        0

# %% [markdown]
# # fancy indexing

# %% [markdown]
# In[77]:

# %%
students.loc[['maryam' , 'ayesha' , 'alia']]
# Out:
#         iq  marks  package
# name
# maryam  98    134       34
# ayesha  67     23       45
# alia     0      0        0

# %% [markdown]
# In[78]:

# %% [markdown]
# ###################   iloc is also applicable in this   ###########################################

# %% [markdown]
# In[79]:

# %%
students
# Out:
#          iq  marks  package
# name
# kainat  100    140       16
# maryam   98    134       34
# alisha   45     67       23
# ayesha   67     23       45
# abeera    0      0        0
# alia      0      0        0

# %% [markdown]
# In[80]:

# %%
students.iloc[1]
# Out:
# iq          98
# marks      134
# package     34
# Name: maryam, dtype: int64

# %% [markdown]
# # students.iloc['alisha']   ----------------> not possible

# %% [markdown]
# In[81]:

# %%
students.iloc[1 : 5]
# Out:
#         iq  marks  package
# name
# maryam  98    134       34
# alisha  45     67       23
# ayesha  67     23       45
# abeera   0      0        0

# %% [markdown]
# In[82]:

# %%
students.iloc[0 : 5 : 2]
# Out:
#          iq  marks  package
# name
# kainat  100    140       16
# alisha   45     67       23
# abeera    0      0        0

# %% [markdown]
# # selecting both rows and columns

# %% [markdown]
# In[83]:

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# In[85]:

# %%
movies.iloc[0:3 , 0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# In[87]:

# %%
movies.loc[0:2 , 'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# # Filtering a dataframe

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %% [markdown]
# # Find all final winners

# %%
new_data = ipl[ipl['MatchNumber'] == 'Final']

# %%
new_data
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
new_data[['Season' , 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %% [markdown]
# # also write in one line

# %%
new_data = ipl[ipl['MatchNumber'] == 'Final'][['Season' , 'WinningTeam']]

# %%
new_data
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %% [markdown]
# # how many super over finishes have occured

# %%
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
ipl['SuperOver'] == 'Y'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: SuperOver, Length: 950, dtype: bool

# %%
ipl[ipl['SuperOver']== 'Y']
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %% [markdown]
# # how many superover matches use shape to get number of rows

# %%
ipl[ipl['SuperOver']== 'Y'].shape
# Out:
# (14, 20)

# %%
ipl[ipl['SuperOver']== 'Y'].shape[0]
# Out:
# 14

# %% [markdown]
# # how many matches has csk won in kolkata

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['City'] == 'Kolkata'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 945     True
# 946    False
# 947    False
# 948    False
# 949    False
# Name: City, Length: 950, dtype: bool

# %%
ipl[ipl['City'] == 'Kolkata']
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 207        Kolkata Knight Riders               Mumbai Indians
# ...

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')]    #------------------> bitwise and (used for binary operations)
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape
# Out:
# (5, 21)

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %% [markdown]
# # Toss  winner is a match winner in percentage

# %%
ipl['TossWinner'] == ipl['WinningTeam']
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948     True
# 949    False
# Length: 950, dtype: bool

# %%
ipl[ipl['TossWinner'] == ipl['WinningTeam']]
# Out:
#           ID         City        Date   Season  MatchNumber  \
# 1    1312199    Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197      Kolkata  2022-05-24     2022  Qualifier 1
# 5    1304115       Mumbai  2022-05-21     2022           69
# 8    1304112  Navi Mumbai  2022-05-18     2022           66
# 11   1304109       Mumbai  2022-05-15     2022           63
# ..       ...          ...         ...      ...          ...
# 935   335996    Bangalore  2008-04-28  2007/08           15
# 937   335994       Mumbai  2008-04-27  2007/08           14
# 939   335992    Bangalore  2008-04-26  2007/08           12
# 941   335990    Hyderabad  2008-04-24  2007/08            9
# 948   335983   Chandigarh  2008-04-19  2007/08            2
#
#                            Team1                  Team2  \
# 1    Royal Challengers Bangalore       Rajasthan Royals
# 3               Rajasthan Royals         Gujarat Titans
# 5                 Delhi Capitals         Mumbai Indians
# ...

# %%
ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]
# Out:
# 489

# %%
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])* 100
# Out:
# 51.473684210526315

# %% [markdown]
# # movies with rating higher than 8 and votes > 10000

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %% [markdown]
# # action movies with the rating higher than 7.5

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
movies['genres']
# Out:
# 0       Action|Drama|War
# 1                    War
# 2        Biography|Drama
# 3            Crime|Drama
# 4                  Drama
#               ...
# 1624               Drama
# 1625               Drama
# 1626        Comedy|Drama
# 1627              Action
# 1628       Drama|Romance
# Name: genres, Length: 1629, dtype: object

# %%
movies['genres'].str

# %%
movies['genres'].str.split('|')
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 1624                 [Drama]
# 1625                 [Drama]
# 1626         [Comedy, Drama]
# 1627                [Action]
# 1628        [Drama, Romance]
# Name: genres, Length: 1629, dtype: object

# %%
mask=movies['genres'].str.split('|').apply(lambda x : 'Action' in x)

# %%
mask1=movies['imdb_rating'] > 7.5

# %%
movies[mask & mask1].shape[0]
# Out:
# 33

# %%
############################# Also use

# %%
mask=movies['genres'].str.contains("Action")

# %%
mask1=movies['imdb_rating'] > 7.5

# %%
movies[mask & mask1].shape[0]
# Out:
# 33

# %% [markdown]
# # Write a function that can return the track record of two teams against each other

# %%
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
#
#                    WinningTeam    WonBy Margin  method Player_of_Match  \
# 0               Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1             Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
# ...

# %%
team_1=ipl[ipl['Team1']== ipl['WinningTeam']].shape
team_1
# Out:
# (480, 21)

# %%
team_2=ipl[(ipl['Team2'])== (ipl['WinningTeam'])].shape
team_2
# Out:
# (466, 21)

# %% [markdown]
# # Adding new columns:

# %%
movies['Country'] = 'India'

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date', 'Country'],
#       dtype='object')

# %% [markdown]
# # existing one

# %%
movies['actors']
new_data =movies.dropna()

# %%
movies['Lead Actor'] = new_data['actors'].str.split('|').apply(lambda x : x[0])

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date', 'Country', 'Lead Actor'],
#       dtype='object')

# %% [markdown]
# # important dataframe functions

# %% [markdown]
# # astype

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID']=ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
